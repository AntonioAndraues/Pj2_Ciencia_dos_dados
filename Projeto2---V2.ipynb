# %% [markdown]
# # Projeto 2 - Classificador Automático de Sentimento
#
# Você foi contratado por uma empresa parar analisar como os clientes estão reagindo a um determinado produto no Twitter. A empresa deseja que você crie um programa que irá analisar as mensagens disponíveis e classificará como "relevante" ou "irrelevante". Com isso ela deseja que mensagens negativas, que denigrem o nome do produto, ou que mereçam destaque, disparem um foco de atenção da área de marketing.<br /><br />
# Como aluno de Ciência dos Dados, você lembrou do Teorema de Bayes, mais especificamente do Classificador Naive-Bayes, que é largamente utilizado em filtros anti-spam de e-mails. O classificador permite calcular qual a probabilidade de uma mensagem ser relevante dadas as palavras em seu conteúdo.<br /><br />
# Para realizar o MVP (*minimum viable product*) do projeto, você precisa implementar uma versão do classificador que "aprende" o que é relevante com uma base de treinamento e compara a performance dos resultados com uma base de testes.<br /><br />
# Após validado, o seu protótipo poderá também capturar e classificar automaticamente as mensagens da plataforma.
#
# ## Informações do Projeto
#
# Prazo: 13/Set até às 23:59.<br />
# Grupo: 1 ou 2 pessoas.<br /><br />
# Entregáveis via GitHub:
# * Arquivo notebook com o código do classificador, seguindo as orientações abaixo.
# * Arquivo Excel com as bases de treinamento e teste totalmente classificado.
#
# **NÃO disponibilizar o arquivo com os *access keys/tokens* do Twitter.**
#
#
# ### Check 3:
#
# Até o dia 06 de Setembro às 23:59, o notebook e o xlsx devem estar no Github com as seguintes evidências:
#     * Conta no twitter criada.
#     * Produto escolhido.
#     * Arquivo Excel contendo a base de treinamento e teste já classificado.
#
# Sugestão de leitura:<br />
# http://docs.tweepy.org/en/v3.5.0/index.html<br />
# https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/

# %% [markdown]
# ___
#
# ## Preparando o ambiente
#
# Instalando a biblioteca *tweepy* para realizar a conexão com o Twitter:

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

# %% [markdown]
# Importando as Bibliotecas que serão utilizadas. Esteja livre para adicionar outras.

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# ___
# ## Autenticando no  Twitter
#
# Para realizar a captura dos dados é necessário ter uma conta cadastrada no twitter:
#
# * Conta: ***[Preencha aqui o id da sua conta. Ex: @fulano ]***
#
#
# 1. Caso ainda não tenha uma: https://twitter.com/signup
# 1. Depois é necessário registrar um app para usar a biblioteca: https://apps.twitter.com/
# 1. Dentro do registro do App, na aba Keys and Access Tokens, anotar os seguintes campos:
#     1. Consumer Key (API Key)
#     1. Consumer Secret (API Secret)
# 1. Mais abaixo, gere um Token e anote também:
#     1. Access Token
#     1. Access Token Secret
#
# 1. Preencha os valores no arquivo "auth.pass"
#
# **ATENÇÃO**: Nunca divulgue os dados desse arquivo online (GitHub, etc). Ele contém as chaves necessárias para realizar as operações no twitter de forma automática e portanto é equivalente a ser "hackeado". De posse desses dados, pessoas mal intencionadas podem fazer todas as operações manuais (tweetar, seguir, bloquear/desbloquear, listar os seguidores, etc). Para efeito do projeto, esse arquivo não precisa ser entregue!!!

# %%
#Dados de autenticação do twitter:

#Coloque aqui o identificador da conta no twitter: @fulano

#leitura do arquivo no formato JSON
with open('auth.pass') as fp:    
    data = json.load(fp)

#Configurando a biblioteca. Não modificar
auth = tweepy.OAuthHandler(data['consumer_key'], data['consumer_secret'])
auth.set_access_token(data['access_token'], data['access_token_secret'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-71cd346a41cc> in <module>()
#       4
#       5 #leitura do arquivo no formato JSON
# ----> 6 with open('auth.pass') as fp:
#       7     data = json.load(fp)
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: 'auth.pass'

# %% [markdown]
# ___
# ## Coletando Dados
#
# Agora vamos coletar os dados. Tenha em mente que dependendo do produto escolhido, não haverá uma quantidade significativa de mensagens, ou ainda poder haver muitos retweets.<br /><br />
# Configurando:

# %%
#Produto escolhido:
produto = 'PUB'

#Quantidade mínima de mensagens capturadas:
n = 500
#Quantidade mínima de mensagens para a base de treinamento:
t = 300

#Filtro de língua, escolha uma na tabela ISO 639-1.
lang = 'pt'

# %% [markdown]
# Capturando os dados do twitter:

# %%
#Cria um objeto para a captura
api = tweepy.API(auth)

#Inicia a captura, para mais detalhes: ver a documentação do tweepy
i = 1
msgs = []
for msg in tweepy.Cursor(api.search, q=produto, lang=lang).items():    
    msgs.append(msg.text.lower())
    i += 1
    if i > n:
        break

#Embaralhando as mensagens para reduzir um possível viés
shuffle(msgs)

# %% [markdown]
# Salvando os dados em uma planilha Excel:

# %%
#Verifica se o arquivo não existe para não substituir um conjunto pronto
if not os.path.isfile('./{0}.xlsx'.format(produto)):
    
    #Abre o arquivo para escrita
    writer = pd.ExcelWriter('{0}.xlsx'.format(produto))

    #divide o conjunto de mensagens em duas planilhas
    dft = pd.DataFrame({'Treinamento' : pd.Series(msgs[:t])})
    dft.to_excel(excel_writer = writer, sheet_name = 'Treinamento', index = False)

    dfc = pd.DataFrame({'Teste' : pd.Series(msgs[t:])})
    dfc.to_excel(excel_writer = writer, sheet_name = 'Teste', index = False)

    #fecha o arquivo
    writer.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-304c5b1b8769> in <module>()
#       1 #Verifica se o arquivo não existe para não substituir um conjunto pronto
# ----> 2 if not os.path.isfile('./{0}.xlsx'.format(produto)):
#       3
#       4     #Abre o arquivo para escrita
#       5     writer = pd.ExcelWriter('{0}.xlsx'.format(produto))
#
# NameError: name 'produto' is not defined

# %% [markdown]
# ___
# ## Classificando as Mensagens
#
# Agora você deve abrir o arquivo Excel com as mensagens capturadas e classificar na Coluna B se a mensagem é relevante ou não.<br />
# Não se esqueça de colocar um nome para a coluna na célula **B1**.<br /><br />
# Fazer o mesmo na planilha de Controle.
#
# ___
# ## Montando o Classificador Naive-Bayes
#
# Com a base de treinamento montada, comece a desenvolver o classificador. Escreva o seu código abaixo:
#
# Opcionalmente:
# * Limpar as mensagens removendo os caracteres: enter, :, ", ', (, ), etc. Não remover emojis.<br />
# * Corrigir separação de espaços entre palavras e/ou emojis.
# * Propor outras limpezas/transformações que não afetem a qualidade da informação.

# %%
#primeiro passo, converter em uma tabela de frequencia

dados=pd.read_excel('PUBG.xlsx')

# %%
dados['Relevancia']=dados["Relevancia"].astype('category')
dados["Relevancia"].cat.categories = ["Sim", "Não"]

# %%
dados.head()
# Out:
#                                          Treinamento Relevancia
# 0  live! bora jogar?\nhttps://t.co/r7byt6hstd\n#l...        Não
# 1  assistindo o menino @tecnoshlol para ficar bom...        Sim
# 2  rt @videogamerzbr: sorteio de uma key de battl...        Não
# 3                          pubg time via restream.io        Não
# 4  rt @otiozero: último dia de pubg no canal! vem...        Não

# %%
dados.Relevancia.value_counts(True)
#primeiro passo, converter em uma tabela de frequencia

#filter(str.isalnum,dados.Treinamento)

# ''.join(e for e in dados if e.isalnum())
# dados(dados['Treinamento'].split())


import string

def corrigirpontuacao(text):
    for punctuation in string.punctuation:
        text=text.replace(punctuation,'')
    return text
    
    
dados['Treinamento']=dados['Treinamento'].apply(corrigirpontuacao)
dados.Treinamento=dados.Treinamento.str.replace("  "," ")
dados.Treinamento=dados.Treinamento.str.replace("\n","")
dados.head(1)
# Out:
#                                          Treinamento Relevancia
# 0  live bora jogarhttpstcor7byt6hstdlive stream t...        Não

# %%
#Importa excel e filtra em dados relevantes e irrelevantes
dados2=dados
dados2=dados2.iloc[:,[0,1]]
dados2['Relevancia']=dados2["Relevancia"].astype('category')
dados2["Relevancia"].cat.categories = ["Sim", "Não"]
relevantesDados2=dados2[(dados2.Relevancia=="Sim")]
irrelevanteDados2=dados2[(dados2.Relevancia=="Não")]
# Passa o conteudo de cada frase relevante pra uma lista
relevanteslinhas=relevantesDados2.shape
relevanteslinhas=relevanteslinhas[0]
c=0
relevante=[]
while c<relevanteslinhas:
    cell=relevantesDados2.iloc[[c],[0]]
    cell=str(cell)
    relevante.append(cell)
    c=c+1
#Faz o mesmo para os tweets irrelevantes
irrelevantelinhas=irrelevanteDados2.shape
irrelevantelinhas=irrelevantelinhas[0]
c=0
irrelevante=[]
while c<irrelevantelinhas:
    cell=irrelevanteDados2.iloc[[c],[0]]
    cell=str(cell)
    irrelevante.append(cell)
    c=c+1

# %%
relevantesDados2['Treinamento']=relevantesDados2['Treinamento'].str.split(pat=None,n=-1,expand=False)
relevantesDados2=relevantesDados2['Treinamento'].sum(axis=None, skipna=None, level=None, numeric_only=None)

irrelevanteDados2['Treinamento']=irrelevanteDados2['Treinamento'].str.split(pat=None,n=-1,expand=False)
irrelevanteDados2=irrelevanteDados2['Treinamento'].sum(axis=None, skipna=None, level=None, numeric_only=None)
# Out:
# C:\Users\andra\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\andra\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# relevantesdic={}
# c=0
# while c<len(relevantesDados2):
#     if relevantesDados2[c] in relevantesdic:
#         relevantesdic[relevantesDados2[c]]=relevantesdic[relevantesDados2[c]]+1
#     else:
#         relevantesdic[relevantesDados2[c]]=1
#     z=+1
# relevantesdic
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-573c11ae1a81> in <module>()
#       1 relevantesdic={}
#       2 c=0
# ----> 3 while c<len(relevantesDados2):
#       4     if relevantesDados2[c] in relevantesdic:
#       5         relevantesdic[relevantesDados2[c]]=relevantesdic[relevantesDados2[c]]+1
#
# KeyboardInterrupt:

# %%
irrelevantedic={}
c=0
while c<len(irrelevanteDados2):
    if irrelevanteDados2[c] in irrelevantedic:
        irrelevantedic[irrelevanteDados2[c]]=irrelevantedic[irrelevanteDados2[c]]+1
    else:
        irrelevantedic[irrelevanteDados2[c]]=1
    c=c+1
irrelevantedic
# Out:
# {'1': 12,
#  '10': 3,
#  '100': 4,
#  '1060': 13,
#  '1200': 11,
#  '1200gtx': 2,
#  '127': 4,
#  '129': 2,
#  '14h30': 1,
#  '16bits': 1,
#  '2': 1,
#  '230': 1,
#  '2600': 1,
#  '27': 3,
#  '271': 3,
#  '3': 14,
#  '32': 1,
#  '38': 1,
#  '4': 1,
#  '45': 1,
#  '5': 3,
#  '580': 11,
#  '600': 1,
#  '7gtpubg': 1,
#  '8': 5,
#  '8300rx': 11,
#  '8300rx580': 2,
#  '9': 2,
#  'a': 13,
#  'acads': 1,
#  'added': 1,
#  'adicionei': 3,
#  'agachar': 1,
#  'agora': 1,
#  'ai': 1,
#  'airsoft': 4,
#  'airsoftguns': 1,
#  'ak': 3,
#  'al': 1,
#  'all': 2,
#  'amor': 3,
#  'amp': 3,
#  'and': 1,
#  'anthony': 1,
#  'ao': 4,
#  'aquele': 2,
#  'aqui': 9,
#  'ar': 1,
#  'arma': 3,
#  'around': 1,
#  'as': 1,
#  'assista': 1,
#  'at': 1,
#  'atenção': 1,
#  'aumentar': 4,
#  'bad': 1,
#  'balaço': 1,
#  'band': 1,
#  'battlegrounds': 12,
#  'battlegroundsparticipe': 4,
#  'bdm': 1,
#  'be': 1,
#  'bem': 1,
#  'bf1': 1,
#  'bo3': 2,
#  'boa': 1,
#  'boomheadshot': 1,
#  'bora': 2,
#  'bota': 1,
#  'brhttpstco1t668cavl2tecnoshlol': 1,
#  'brisasuavelive': 3,
#  'bug': 1,
#  'buzina': 1,
#  'cabr': 1,
#  'café': 1,
#  'caganeira': 2,
#  'canal': 11,
#  'canalpubg': 1,
#  'carai': 1,
#  'catioros': 1,
#  'caveirinha': 1,
#  'cheat': 1,
#  'clips': 2,
#  'com': 18,
#  'comentários': 7,
#  'começando': 1,
#  'como': 5,
#  'compares': 1,
#  'competitivo': 1,
#  'compra': 1,
#  'confirmado': 1,
#  'corre': 1,
#  'cover': 1,
#  'cruzada': 3,
#  'csgo': 4,
#  'csgozada': 1,
#  'cshttpstco1r1p4gh4b6httpstco5xi0vluxpztudo': 1,
#  'd': 1,
#  'da': 12,
#  'darkzone95': 1,
#  'day': 1,
#  'de': 111,
#  'death': 1,
#  'deixa': 1,
#  'demo': 3,
#  'denissnider': 3,
#  'desci': 1,
#  'dia': 11,
#  'direto': 3,
#  'discoverys': 1,
#  'divertido': 1,
#  'do': 30,
#  'dominando': 1,
#  'dota': 1,
#  'duo': 3,
#  'duplo': 13,
#  'duxtromb': 1,
#  'e': 28,
#  'eduardoduccigne': 1,
#  'el': 1,
#  'em': 3,
#  'encontrar': 1,
#  'engraçados': 1,
#  'ensinar': 1,
#  'entenderão': 2,
#  'entregaaaa🎁duo': 3,
#  'ep': 1,
#  'esp': 1,
#  'estou': 1,
#  'eu': 1,
#  'exclusivos': 1,
#  'faceit': 1,
#  'fails': 1,
#  'fallen': 1,
#  'fazendo': 1,
#  'fazer': 1,
#  'fb': 1,
#  'felicidades': 1,
#  'foi': 1,
#  'fps': 4,
#  'free': 1,
#  'frente': 1,
#  'ft': 3,
#  'fx': 13,
#  'fã': 1,
#  'game': 1,
#  'gamer': 1,
#  'gamerpatife': 1,
#  'gameskayky': 1,
#  'geral': 1,
#  'global': 1,
#  'goalvamos': 1,
#  'god': 1,
#  'gordox': 1,
#  'gostei': 74,
#  'grande': 3,
#  'grimmmz': 1,
#  'gringo': 1,
#  'gt2': 1,
#  'gtaula': 1,
#  'gttomo': 1,
#  'gtx': 11,
#  'gtúltimos': 1,
#  'guizaokemen': 1,
#  'gustavodocil': 1,
#  'hhahahha': 1,
#  'highlights': 7,
#  'hightlights': 1,
#  'hj': 1,
#  'hoje': 1,
#  'hora': 3,
#  'how': 1,
#  'httpstco0ltw4rac0k': 1,
#  'httpstco0yfokbug8g': 1,
#  'httpstco14ehjzcqtzúltimo': 1,
#  'httpstco1bf4zz6gbm': 1,
#  'httpstco1djokhrmk2': 1,
#  'httpstco2btpcrnl0h': 1,
#  'httpstco2ce1znit62': 1,
#  'httpstco2vjdpkpzga': 1,
#  'httpstco3a1hqclgac': 1,
#  'httpstco3nkmienrnu': 1,
#  'httpstco4crf9sewvl': 1,
#  'httpstco4f3cu4xwys': 2,
#  'httpstco4h3jh7xf7w': 1,
#  'httpstco4yqnzuakne🔴': 1,
#  'httpstco4yzwie4tio': 1,
#  'httpstco50h4qfvgcn': 1,
#  'httpstco5qhipq0jbi': 1,
#  'httpstco5zcok8yrpf': 1,
#  'httpstco6fvnbexqfd': 1,
#  'httpstco6itxwbti2júltimo': 1,
#  'httpstco6jlvbbyzyb': 1,
#  'httpstco6peecxrrbi': 1,
#  'httpstco6tblaql4cz': 1,
#  'httpstco7buk9ikezn': 1,
#  'httpstco7ek3h81ze3': 1,
#  'httpstco8cqsxxkvrm': 1,
#  'httpstco9lez4cfk4a': 1,
#  'httpstco9tmqbrjroe': 1,
#  'httpstco9z5tcs3kku': 1,
#  'httpstcoajjqdnpkew': 1,
#  'httpstcoaooojpnolh': 1,
#  'httpstcob8g2flh0h3último': 1,
#  'httpstcobe8evditov': 1,
#  'httpstcobfegyu2pit': 1,
#  'httpstcobrqswholve': 1,
#  'httpstcobsqg65p7gr': 1,
#  'httpstcoc5a9rhcsbc': 1,
#  'httpstcoce6thpynzk': 1,
#  'httpstcocf224qb04c': 1,
#  'httpstcocj2hh6tv2s': 1,
#  'httpstcoclkqiidwbg': 1,
#  'httpstcocoe3ujhdln': 1,
#  'httpstcodmgzoxfngm': 1,
#  'httpstcoelm8ggepor': 1,
#  'httpstcoeomqvtcqrk': 1,
#  'httpstcof68y14uadn': 1,
#  'httpstcofkqqs9rwwz': 1,
#  'httpstcofpa0b97lra': 1,
#  'httpstcofyjumzmy3k': 1,
#  'httpstcogiw1rt8puqçando': 1,
#  'httpstcogklokgfoej': 1,
#  'httpstcogzq8w0thpi': 1,
#  'httpstcoh6qpmixstg': 2,
#  'httpstcohcssirbkbv': 1,
#  'httpstcohfl1lefvrr': 1,
#  'httpstcoiwhnykpmzc': 1,
#  'httpstcoj4l1vhzoeh': 1,
#  'httpstcoj4xtfdd9xd': 1,
#  'httpstcoj8thbxhxdm': 1,
#  'httpstcojf9gjfdql2': 1,
#  'httpstcojgstvar9joúltimo': 1,
#  'httpstcok3qpsmbnappubg': 4,
#  'httpstcok8zgrjtag3': 1,
#  'httpstcokggzvs1wh3': 1,
#  'httpstcoklshe4hgrn': 1,
#  'httpstcoksk4qwsrdeúltimo': 1,
#  'httpstcokvtpulqfc9': 1,
#  'httpstcolahjgif1cj': 1,
#  'httpstcolnxi5lxexf': 1,
#  'httpstcoltcxsgdxic': 1,
#  'httpstcomgpcbl7qtj': 1,
#  'httpstcomjgb6wyhzf🔴': 1,
#  'httpstcomyzrzqiuin': 1,
#  'httpstcomzzluolfez': 1,
#  'httpstcon7lzz9xqhv': 1,
#  'httpstconxmjytcdvw': 2,
#  'httpstconyubv52vtw': 1,
#  'httpstcoo2mt8ygfjf': 1,
#  'httpstcoonz2lqllto': 1,
#  'httpstcoovaofzf4g5': 1,
#  'httpstcoowzhyakwuy': 1,
#  'httpstcopfsafxo5zr': 1,
#  'httpstcopnvnmwxeqr': 1,
#  'httpstcoprc7tosqrsúltimo': 1,
#  'httpstcopttmgre6ho': 2,
#  'httpstcopuledejnym': 1,
#  'httpstcoq5gtafbfrn': 1,
#  'httpstcoq9pxu3w3y1': 1,
#  'httpstcoqsdlc7et0g': 1,
#  'httpstcor2ezcuhfdy': 1,
#  'httpstcor3l6czb5sjdocil': 1,
#  'httpstcort3glbrlo3': 1,
#  'httpstcorx0kcajvf2': 1,
#  'httpstcos7w9t1ojuj': 1,
#  'httpstcos8swv86vhj': 1,
#  'httpstcosi6lx5llpe': 1,
#  'httpstcotmpjsvlrnn': 1,
#  'httpstcotpos6yni2w': 1,
#  'httpstcotrsetbjjxc': 1,
#  'httpstcotrs…': 3,
#  'httpstcoue3mgnp6rw': 1,
#  'httpstcouohnj5e0ns': 1,
#  'httpstcovnwstp6olk': 1,
#  'httpstcovrlrp0qeny': 1,
#  'httpstcovtmxyks9e7': 1,
#  'httpstcovuvw9tvvoq': 1,
#  'httpstcovyzhfbkaqc': 1,
#  'httpstcow3olwqd92h': 1,
#  'httpstcow7kaagolo6': 1,
#  'httpstcow8nla0hvwi': 1,
#  'httpstcowlrbeqkgkd': 1,
#  'httpstcowolnpbkdub': 1,
#  'httpstcowsb6gh0kiz': 1,
#  'httpstcox2rmwrznhr': 1,
#  'httpstcoxhoiv3zl0t': 1,
#  'httpstcoxld1mnpgam': 3,
#  'httpstcoxrmve60ujd': 1,
#  'httpstcoy7ow7pn165': 1,
#  'httpstcoym82rwolxd': 1,
#  'httpstcoymf36hz9wm': 1,
#  'httpstcoympiogki1púltimo': 1,
#  'httpstcoyuvw0aeb7o': 1,
#  'httpstcoyzyetrwicf': 1,
#  'httpstcozjuq8erqb7бесплатный': 1,
#  'httpstcozo9uhbtxy5': 1,
#  'httpstcozy4y0ml49v': 1,
#  'httpstcozybzomeod2tamo': 1,
#  'humilde': 3,
#  'humildehttpstco5nky40rw82': 1,
#  'i': 1,
#  'i9mha': 1,
#  'ii': 3,
#  'in': 5,
#  'inatividade': 1,
#  'insana': 1,
#  'insta': 1,
#  'irá': 1,
#  'island': 1,
#  'jhonson': 1,
#  'joga': 2,
#  'jogadas': 2,
#  'jogadores': 2,
#  'jogando': 7,
#  'jogar': 3,
#  'jogarhttpstcor7byt6hstdlive': 1,
#  'jogo': 5,
#  'key': 4,
#  'kills': 5,
#  'klllgame': 1,
#  'league': 1,
#  'lendo': 7,
#  'liberar': 4,
#  'life': 5,
#  'ligarush': 1,
#  'live': 10,
#  'livestream': 10,
#  'lobby': 2,
#  'logo': 1,
#  'lol': 1,
#  'loukaspelodenis': 3,
#  'luls': 2,
#  'lvl': 1,
#  'lá': 1,
#  'mais': 5,
#  'man': 1,
#  'manhã': 2,
#  'mata': 1,
#  'melaotreze': 1,
#  'melhor': 3,
#  'melhores': 5,
#  'memoria': 4,
#  'mesmo': 1,
#  'mestre': 1,
#  'mgnbrasil': 2,
#  'misteriosa250': 1,
#  'mixrj': 1,
#  'mode': 1,
#  'momento': 1,
#  'momentos': 6,
#  'moments': 1,
#  'morte': 1,
#  'mrsmxkez': 2,
#  'muito': 4,
#  'muna': 1,
#  'mytzz': 1,
#  'na': 3,
#  'nessa': 1,
#  'neymar': 1,
#  'nightzzzzzzz': 2,
#  'ninextt': 1,
#  'ninguém': 1,
#  'nino': 1,
#  'no': 38,
#  'nois': 1,
#  'noite': 6,
#  'nosso': 2,
#  'novos': 1,
#  'não': 1,
#  'o': 19,
#  'obrigado': 1,
#  'of': 1,
#  'ohttpstcoaw1rbqaz5x': 1,
#  'on': 3,
#  'online': 3,
#  'os': 1,
#  'otiozero': 3,
#  'ou': 1,
#  'pai': 1,
#  'para': 7,
#  'parabéns': 1,
#  'participando': 1,
#  'partida': 1,
#  'pc': 3,
#  'pela': 1,
#  'penguins': 1,
#  'percogtfeels': 1,
#  'pergunta': 1,
#  'pior': 1,
#  'planetvaleria': 1,
#  'playerunknowns': 6,
#  'playerunknownsbattlegrounds': 5,
#  'playing': 1,
#  'playlist': 4,
#  'pm': 1,
#  'por': 1,
#  'porque': 2,
#  'pra': 1,
#  'prata': 3,
#  'pro': 1,
#  'pub': 3,
#  'pubattlegrounds': 1,
#  'pubg': 131,
#  'pubg1': 1,
#  'pubg1〜3vain2': 1,
#  'pubgclips…': 1,
#  'pubggoooooohttpstcof6d2gwiglrrt': 3,
#  'pubghispano': 1,
#  'pubghttpstcomwu1tpm922roadto4k': 1,
#  'pubghttpstcots1idssuz7': 2,
#  'pubghttpstcoymc1zykzk7': 1,
#  'pubghttpstcoyrx3v9gdjm': 1,
#  'pubgpartners': 1,
#  'pubgtwitchtvonline': 1,
#  'pular': 1,
#  'qave': 1,
#  'qua': 2,
#  'que': 2,
#  'race': 1,
#  'ragefu': 1,
#  'raider': 3,
#  'ram': 4,
#  'random': 1,
#  'rank': 4,
#  'rave': 1,
#  'razer': 3,
#  'ready': 1,
#  'real': 5,
#  'rebentar': 1,
#  'remastered': 3,
#  'respeita': 1,
#  'resposta': 1,
#  'restreamio': 2,
#  'risas': 2,
#  'road': 1,
#  'rocam': 1,
#  'rocket': 1,
#  'rolando': 1,
#  'rolar': 3,
#  'rp': 1,
#  'rp400': 1,
#  'rt': 24,
#  'rubber': 1,
#  'rumo1k': 3,
#  'rumoaos800': 6,
#  'ryzen': 13,
#  'sa': 1,
#  'santii99': 1,
#  'se': 1,
#  'seguidores': 3,
#  'semana': 2,
#  'seu': 1,
#  'shroud': 2,
#  'simulator': 2,
#  'skin': 1,
#  'skins': 2,
#  'skinsgambling': 2,
#  'skipnho': 1,
#  'sobre': 2,
#  'sobrevivi': 1,
#  'solo': 5,
#  'solvedresolvido': 1,
#  'some': 1,
#  'sorteio': 7,
#  'sou': 1,
#  'so…': 4,
#  'squad': 3,
#  'starts': 1,
#  'steam': 2,
#  'stock': 2,
#  'stockoc': 11,
#  'stream': 8,
#  'stuffi': 1,
#  'sub': 4,
#  'subir': 1,
#  'subs': 2,
#  'só': 1,
#  's…': 3,
#  'ta': 1,
#  'também': 2,
#  'tarde': 2,
#  'tb': 1,
#  'tecnosh': 5,
#  'tecnoshlol': 1,
#  'tem': 2,
#  'temos': 1,
#  'tentando': 1,
#  'teste': 13,
#  'texture': 1,
#  'the': 1,
#  'then': 1,
#  'time': 1,
#  'tixinhadois': 1,
#  'to': 4,
#  'tomb': 3,
#  'top': 2,
#  'top1': 1,
#  'top🤘httpstcoe0utwrlvbe': 3,
#  'trapalhada': 2,
#  'trutsdew': 1,
#  'tua': 1,
#  'tuta': 1,
#  'twitch': 3,
#  'twitchtvgaming': 1,
#  'tô': 1,
#  'um': 82,
#  'uma': 10,
#  'undertale': 1,
#  'unlucky': 1,
#  'vai': 4,
#  'valor': 1,
#  'vamo': 1,
#  'vamos': 1,
#  'vemhttpstcopvrgeafl8ehttpstcopvrgeafl8ehttpstcopvrgeafl8e': 4,
#  'vencemos': 2,
#  'venez': 1,
#  'ver': 1,
#  'vgbr1k': 4,
#  'via': 13,
#  'video': 3,
#  'videogamerzbr': 4,
#  'visdom': 1,
#  'visita': 1,
#  'vitórias': 1,
#  'vivo': 4,
#  'vivosgtcorro': 1,
#  'vo': 1,
#  'você': 2,
#  'vs': 1,
#  'vídeo': 76,
#  'war': 1,
#  'wh': 1,
#  'williangordox': 3,
#  'win': 1,
#  'with': 2,
#  'xbox': 1,
#  'xone': 1,
#  'youtube': 89,
#  'youtubegaming': 2,
#  'zueira': 1,
#  'à': 2,
#  'águia': 1,
#  'é': 5,
#  'ésfish': 1,
#  'último': 4,
#  '☜═㋡': 3,
#  '🐶': 1,
#  '🔴': 1,
#  '😂😂😂': 2,
#  '🤔': 1}

# %% [markdown]
# ___
# ## Verificando a performance
#
# Agora você deve testar o seu Classificador com a base de Testes.<br /><br />
#
# Você deve extrair as seguintes medidas:
# * Porcentagem de positivos falsos (marcados como relevante mas não são relevantes)
# * Porcentagem de positivos verdadeiros (marcado como relevante e são relevantes)
# * Porcentagem de negativos verdadeiros (marcado como não relevante e não são relevantes)
# * Porcentagem de negativos falsos (marcado como não relevante e são relevantes)
#
# Opcionalmente:
# * Criar categorias intermediárias de relevância baseado na diferença de probabilidades. Exemplo: muito relevante, relevante, neutro, irrelevante e muito irrelevante.

# %% [markdown]
# ___
# ## Concluindo
#
# Escreva aqui a sua conclusão.<br />
# Faça um comparativo qualitativo sobre as medidas obtidas.<br />
# Explique como são tratadas as mensagens com dupla negação e sarcasmo.<br />
# Proponha um plano de expansão. Por que eles devem continuar financiando o seu projeto?<br />
#
# Opcionalmente:
# * Discorrer por que não posso alimentar minha base de Treinamento automaticamente usando o próprio classificador, aplicado a novos tweets.
# * Propor diferentes cenários de uso para o classificador Naive-Bayes. Cenários sem intersecção com este projeto.
# * Sugerir e explicar melhorias reais no classificador com indicações concretas de como implementar (não é preciso codificar, mas indicar como fazer e material de pesquisa sobre o assunto).
